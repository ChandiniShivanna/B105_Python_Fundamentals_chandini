# %%
first_name="Chandini"
last_name="Shivanna"
fullname= f"{first_name} {last_name}"
print(fullname)
# Out:
# Chandini Shivanna

# %%
print(fullname.upper())
# Out:
# CHANDINI SHIVANNA

# %%
msg=f"Keep up ur work {fullname}."

# %%
print(msg)
# Out:
# Keep up ur work Chandini Shivanna.

# %%
#whitespaces

# %%
print("Fav Program :\nJS\nHTML\nCSS\nMongoDB")
# Out:
# Fav Program :
# JS
# HTML
# CSS
# MongoDB

# %%
print("Fav Prog :\n\tJS\n\tHTML\n\tCSS\n\tMongoDB")
# Out:
# Fav Prog :
# 	JS
# 	HTML
# 	CSS
# 	MongoDB

# %%
name=' python'
name1='python '
name2='python'
print(name,name2,name3)
