# %%
#List

# %%
students=['chandini','punarv','jesu','nandu','ashu']
print(students)
# Out:
# ['chandini', 'punarv', 'jesu', 'nandu', 'ashu']

# %%
type(students)
# Out:
# list

# %%
print(students)
# Out:
# ['chandini', 'punarv', 'jesu', 'nandu', 'ashu']

# %%
print(students[1])
# Out:
# punarv

# %%
print(students[3])
# Out:
# nandu

# %%
print(students[5])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 print(students[5])
#
# IndexError: list index out of range

# %%
students.append('crystal')
print(students)
# Out:
# ['chandini', 'punarv', 'jesu', 'nandu', 'ashu', 'crystal']

# %%
students.insert(4,'laddu')
print(students)
# Out:
# ['chandini', 'punarv', 'jesu', 'nandu', 'laddu', 'ashu', 'crystal']

# %%
students[4]='jasmitha'
print(students)
# Out:
# ['chandini', 'punarv', 'jesu', 'nandu', 'jasmitha', 'ashu', 'crystal']

# %%
students(2)
