# %%
#variales
a=2
b=3
c=a+b
print(c)
# Out:
# 5

# %%
#declaring Variables

# rule1: no name space

first name= " Chandini"
print(first name)
# Out:
#   Cell In[4], line 5
#     first name= " Chandini"
#           ^
# SyntaxError: invalid syntax

# %%
first_name= "chandini"  #correct code
print(first_name)
# Out:
# chandini

# %%
#rule 2 : variable should not start with numbers

1name="chandini"
print(1name)
# Out:
#   Cell In[6], line 3
#     1name="chandini"
#     ^
# SyntaxError: invalid decimal literal

# %%
name1="chandini"
print(name1)
# Out:
# chandini

# %%
# rule3 : variables should not contain special characters

@name="chandini"
print(@name)
# Out:
#   Cell In[8], line 3
#     @name="chandini"
#      ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
# String Data type

name= "chandini"
print(name)
# Out:
# chandini

# %%
name1='chandini'
print(name1)
# Out:
# chandini

# %%
type(name)
# Out:
# str

# %%
#methods

name="chandini shivanna"
print(name)
# Out:
# chandini shivanna

# %%
print(name.title()) # title()
# Out:
# Chandini Shivanna

# %%
print(name.upper()) #upper()
# Out:
# CHANDINI SHIVANNA

# %%
print(name.lower()) #lower()
# Out:
# chandini shivanna
